# %% [markdown]
# This notebook will show how to map data using the MapMyCells data products released with the HMBA consensus Basal Ganglia taxonomy.
#
# We are going to start by installing the `cell_type_mapper` (actual backend for MapMyCells) and `abc_atlas_access` (convenient download of other data provided by the AllenInstitute) libraries. You may need to restart your kernel after running these cells so that the notebook will acknoweldge the installed libraries.

# %%
pip install "cell_type_mapper @ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2"
# Out:
# Collecting cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2
#   Cloning https://github.com/alleninstitute/cell_type_mapper.git (to revision rc/v1.5.2) to /private/var/folders/8b/hnw5vq8s20jbpz51wdhd11fr0000gp/T/pip-install-8c53nk7s/cell-type-mapper_0bad1e0b8b984773bf66c09ace614cdc
#   Running command git clone --filter=blob:none --quiet https://github.com/alleninstitute/cell_type_mapper.git /private/var/folders/8b/hnw5vq8s20jbpz51wdhd11fr0000gp/T/pip-install-8c53nk7s/cell-type-mapper_0bad1e0b8b984773bf66c09ace614cdc
#   Running command git checkout -b rc/v1.5.2 --track origin/rc/v1.5.2
#   Switched to a new branch 'rc/v1.5.2'
#   branch 'rc/v1.5.2' set up to track 'origin/rc/v1.5.2'.
#   Resolved https://github.com/alleninstitute/cell_type_mapper.git to commit 2aefd39caf5799555c4bcad6ba437ca9d93d4bfd
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting anndata>=0.11.0 (from cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached anndata-0.11.4-py3-none-any.whl.metadata (9.3 kB)
# Collecting argschema (from cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached argschema-3.0.4-py2.py3-none-any.whl
# Collecting matplotlib (from cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached matplotlib-3.10.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting marshmallow==3.12.2 (from cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached marshmallow-3.12.2-py2.py3-none-any.whl.metadata (7.8 kB)
# Collecting numpy (from cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached numpy-2.2.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (62 kB)
# Collecting pytest (from cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached pytest-8.3.5-py3-none-any.whl.metadata (7.6 kB)
# Collecting pytest-xdist (from cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached pytest_xdist-3.6.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting scipy<1.15.0 (from cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached scipy-1.14.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (60 kB)
# Collecting array-api-compat!=1.5,>1.4 (from anndata>=0.11.0->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached array_api_compat-1.11.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting h5py>=3.7 (from anndata>=0.11.0->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached h5py-3.13.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting natsort (from anndata>=0.11.0->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging>=24.2 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from anndata>=0.11.0->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2) (25.0)
# Collecting pandas!=2.1.0rc0,!=2.1.2,>=1.4 (from anndata>=0.11.0->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (89 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata>=0.11.0->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata>=0.11.0->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata>=0.11.0->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0rc0,!=2.1.2,>=1.4->anndata>=0.11.0->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2) (1.17.0)
# Requirement already satisfied: pyyaml in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from argschema->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2) (6.0.2)
# Collecting contourpy>=1.0.1 (from matplotlib->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached contourpy-1.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached fonttools-4.57.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached kiwisolver-1.4.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Collecting pillow>=8 (from matplotlib->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached pillow-11.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting iniconfig (from pytest->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pluggy<2,>=1.5 (from pytest->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting execnet>=2.1 (from pytest-xdist->cell_type_mapper@ git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2)
#   Using cached execnet-2.1.1-py3-none-any.whl.metadata (2.9 kB)
# Using cached marshmallow-3.12.2-py2.py3-none-any.whl (47 kB)
# Using cached scipy-1.14.1-cp312-cp312-macosx_12_0_arm64.whl (29.9 MB)
# Using cached numpy-2.2.5-cp312-cp312-macosx_11_0_arm64.whl (14.2 MB)
# Using cached anndata-0.11.4-py3-none-any.whl (144 kB)
# Using cached array_api_compat-1.11.2-py3-none-any.whl (53 kB)
# Using cached h5py-3.13.0-cp312-cp312-macosx_11_0_arm64.whl (2.9 MB)
# Using cached pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl (11.4 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached matplotlib-3.10.1-cp312-cp312-macosx_11_0_arm64.whl (8.0 MB)
# Using cached contourpy-1.3.2-cp312-cp312-macosx_11_0_arm64.whl (255 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.57.0-cp312-cp312-macosx_10_13_universal2.whl (2.8 MB)
# Using cached kiwisolver-1.4.8-cp312-cp312-macosx_11_0_arm64.whl (65 kB)
# Using cached pillow-11.2.1-cp312-cp312-macosx_11_0_arm64.whl (3.0 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Using cached pytest-8.3.5-py3-none-any.whl (343 kB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Using cached iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Using cached pytest_xdist-3.6.1-py3-none-any.whl (46 kB)
# Using cached execnet-2.1.1-py3-none-any.whl (40 kB)
# Building wheels for collected packages: cell_type_mapper
#   Building wheel for cell_type_mapper (pyproject.toml) ... done
#   Created wheel for cell_type_mapper: filename=cell_type_mapper-1.5.2-py3-none-any.whl size=1267585 sha256=c64b8f0d1a232526b33ffc1153f30c67df0c81f1987fc6326ff9069a99a1f511
#   Stored in directory: /private/var/folders/8b/hnw5vq8s20jbpz51wdhd11fr0000gp/T/pip-ephem-wheel-cache-w2bychy5/wheels/39/4b/ba/4a4748790aa5c8131acd28a37fb39150691656e4b2ca693527
# Successfully built cell_type_mapper
# Installing collected packages: pytz, tzdata, pyparsing, pluggy, pillow, numpy, natsort, marshmallow, kiwisolver, iniconfig, fonttools, execnet, cycler, array-api-compat, scipy, pytest, pandas, h5py, contourpy, argschema, pytest-xdist, matplotlib, anndata, cell_type_mapper
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24/24 [cell_type_mapper][cell_type_mapper]
# Successfully installed anndata-0.11.4 argschema-3.0.4 array-api-compat-1.11.2 cell_type_mapper-1.5.2 contourpy-1.3.2 cycler-0.12.1 execnet-2.1.1 fonttools-4.57.0 h5py-3.13.0 iniconfig-2.1.0 kiwisolver-1.4.8 marshmallow-3.12.2 matplotlib-3.10.1 natsort-8.4.0 numpy-2.2.5 pandas-2.2.3 pillow-11.2.1 pluggy-1.5.0 pyparsing-3.2.3 pytest-8.3.5 pytest-xdist-3.6.1 pytz-2025.2 scipy-1.14.1 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "abc_atlas_access[notebooks] @ git+https://github.com/alleninstitute/abc_atlas_access.git"
# Out:
# Collecting abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git (from abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Cloning https://github.com/alleninstitute/abc_atlas_access.git to /private/var/folders/8b/hnw5vq8s20jbpz51wdhd11fr0000gp/T/pip-install-i48hugce/abc-atlas-access_ddbb425a58264c86b248be905825cb7b
#   Running command git clone --filter=blob:none --quiet https://github.com/alleninstitute/abc_atlas_access.git /private/var/folders/8b/hnw5vq8s20jbpz51wdhd11fr0000gp/T/pip-install-i48hugce/abc-atlas-access_ddbb425a58264c86b248be905825cb7b
#   Resolved https://github.com/alleninstitute/abc_atlas_access.git to commit a82a6770c99ad166105c3e6fccd47f31ee69b44c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: anndata in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (0.11.4)
# Collecting boto3 (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Downloading boto3-1.38.11-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2.2.5)
# Requirement already satisfied: pandas in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2.2.3)
# Collecting pydantic (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Using cached pydantic-2.11.4-py3-none-any.whl.metadata (66 kB)
# Collecting tqdm (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: matplotlib in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (3.10.1)
# Requirement already satisfied: scipy in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (1.14.1)
# Collecting simpleitk (from abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Downloading simpleitk-2.5.0-cp311-abi3-macosx_11_0_arm64.whl.metadata (7.2 kB)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from anndata->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (1.11.2)
# Requirement already satisfied: h5py>=3.7 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from anndata->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (3.13.0)
# Requirement already satisfied: natsort in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from anndata->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from anndata->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from pandas->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from pandas->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from pandas->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (1.17.0)
# Collecting botocore<1.39.0,>=1.38.11 (from boto3->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Downloading botocore-1.38.11-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.13.0,>=0.12.0 (from boto3->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Using cached s3transfer-0.12.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from botocore<1.39.0,>=1.38.11->boto3->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (2.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from matplotlib->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from matplotlib->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from matplotlib->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from matplotlib->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from matplotlib->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from matplotlib->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (3.2.3)
# Collecting annotated-types>=0.6.0 (from pydantic->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages (from pydantic->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git) (4.13.2)
# Collecting typing-inspection>=0.4.0 (from pydantic->abc_atlas_access@ git+https://github.com/alleninstitute/abc_atlas_access.git->abc_atlas_access[notebooks]@ git+https://github.com/alleninstitute/abc_atlas_access.git)
#   Using cached typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Downloading boto3-1.38.11-py3-none-any.whl (139 kB)
# Downloading botocore-1.38.11-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 23.9 MB/s eta 0:00:00 0:00:01
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached s3transfer-0.12.0-py3-none-any.whl (84 kB)
# Using cached pydantic-2.11.4-py3-none-any.whl (443 kB)
# Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading simpleitk-2.5.0-cp311-abi3-macosx_11_0_arm64.whl (38.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.5/38.5 MB 11.4 MB/s eta 0:00:0000:0100:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Building wheels for collected packages: abc_atlas_access
#   Building wheel for abc_atlas_access (pyproject.toml) ... done
#   Created wheel for abc_atlas_access: filename=abc_atlas_access-0.6.0-py3-none-any.whl size=21653 sha256=50a9d13cfa58e3ca82db8f53725053f420b444ceb17885c3a53c24cc6ea6ec3b
#   Stored in directory: /private/var/folders/8b/hnw5vq8s20jbpz51wdhd11fr0000gp/T/pip-ephem-wheel-cache-tfbr4h4i/wheels/0f/79/3e/7355e6338e46308d9510a8e2f699a9b8d69553bd796698f725
# Successfully built abc_atlas_access
# Installing collected packages: simpleitk, typing-inspection, tqdm, pydantic-core, jmespath, annotated-types, pydantic, botocore, s3transfer, boto3, abc_atlas_access
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [abc_atlas_access][boto3]re]
# Successfully installed abc_atlas_access-0.6.0 annotated-types-0.7.0 boto3-1.38.11 botocore-1.38.11 jmespath-1.0.1 pydantic-2.11.4 pydantic-core-2.33.2 s3transfer-0.12.0 simpleitk-2.5.0 tqdm-4.67.1 typing-inspection-0.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd

import cell_type_mapper
from abc_atlas_access.abc_atlas_cache.abc_project_cache import AbcProjectCache

# %% [markdown]
# To run MapMyCells, you need two supporting data files: [an HDF5 file](https://github.com/AllenInstitute/cell_type_mapper/blob/main/docs/input_data_files/precomputed_stats_file.md) which defines your taxonomy and the average gene expression profiles of the taxons there in, and a [lookup table of marker genes](https://github.com/AllenInstitute/cell_type_mapper/blob/main/docs/input_data_files/marker_gene_lookup.md) for your taxonomy. For the sake of this exercise, let's download those two files for the human basal ganglia data. Refer back [to the main page](https://github.com/AllenInstitute/HMBA_BasalGanglia_Consensus_Taxonomy/blob/main/index.md#cell-type-mapping-with-mapmycells) for the locations of the relevant files for all three species (human, marmoset, and macaque).

# %%
! wget "https://released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com/HMBA/BasalGanglia/BICAN_05072025_pre-print_release/MapMyCells/Human.precomputed_stats.20250507.h5" -O "data/Human.precomputed_stats.20250507.h5"
# Out:
# --2025-05-08 10:07:31--  https://released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com/HMBA/BasalGanglia/BICAN_05072025_pre-print_release/MapMyCells/Human.precomputed_stats.20250507.h5
# Resolving released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com (released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com)... 3.5.85.43, 52.218.232.209, 52.218.153.41, ...
# Connecting to released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com (released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com)|3.5.85.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 755535936 (721M) [binary/octet-stream]
# Saving to: ‘data/Human.precomputed_stats.20250507.h5’
#
# data/Human.precompu 100%[===================>] 720.54M  12.5MB/s    in 60s
#
# 2025-05-08 10:08:31 (12.0 MB/s) - ‘data/Human.precomputed_stats.20250507.h5’ saved [755535936/755535936]

# %%
! wget "https://released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com/HMBA/BasalGanglia/BICAN_05072025_pre-print_release/MapMyCells/Human.query_markers.20250507.json" -O "data/Human.query_markers.20250507.json"
# Out:
# --2025-05-08 10:38:10--  https://released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com/HMBA/BasalGanglia/BICAN_05072025_pre-print_release/MapMyCells/Human.query_markers.20250507.json
# Resolving released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com (released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com)... 52.218.232.161, 52.92.133.26, 3.5.82.215, ...
# Connecting to released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com (released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com)|52.218.232.161|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 837105 (817K) [application/json]
# Saving to: ‘data/Human.query_markers.20250507.json’
#
# data/Human.query_ma 100%[===================>] 817.49K  --.-KB/s    in 0.09s
#
# 2025-05-08 10:38:11 (8.79 MB/s) - ‘data/Human.query_markers.20250507.json’ saved [837105/837105]

# %% [markdown]
# You also need some unlabeled ata to map. We will use [the abc_atlas_access tool](https://alleninstitute.github.io/abc_atlas_access/intro.html) to download some Whole Human Brain data that we can map onto the Basal Ganglia taxonomy. **Note:** we are going to download the non-neuronal data only, not because it is interesting, but because it is small (5 GB as opposed to 32 GB for neuronal data).

# %%
abc_cache = AbcProjectCache.from_cache_dir('abc_cache')

# %%
abc_cache.list_data_files(directory='WHB-10Xv3')
# Out:
# ['WHB-10Xv3-Neurons/log2',
#  'WHB-10Xv3-Neurons/raw',
#  'WHB-10Xv3-Nonneurons/log2',
#  'WHB-10Xv3-Nonneurons/raw']

# %%
unmapped_human_data_path = abc_cache.get_data_path(
    directory='WHB-10Xv3',
    file_name='WHB-10Xv3-Nonneurons/raw'
)
# Out:
# WHB-10Xv3-Nonneurons-raw.h5ad: 100%|██████| 4.75G/4.75G [06:57<00:00, 11.4MMB/s]

# %% [markdown]
# Now we will actually [perform the mapping](https://github.com/AllenInstitute/cell_type_mapper/blob/main/docs/mapping_cells.md).

# %%
from cell_type_mapper.cli.from_specified_markers import FromSpecifiedMarkersRunner

# %%
# paths to files where mapping output will be written
json_dst_path = "results/human_nonneurons_mapping.json"
csv_dst_path = "results/human_nonneruons_mapping.csv"

# the lookup table of marker genes which we downloaded from S3
query_marker_path = "data/Human.query_markers.20250507.json"

# the human-specific precomputed stats file which we downloaded from S3
precomputed_path = "data/Human.precomputed_stats.20250507.h5"

config = {
    "query_path": str(unmapped_human_data_path.resolve().absolute()),
    "extended_result_path": json_dst_path,
    "csv_result_path": csv_dst_path,
    "verbose_csv": True,
    "query_markers": {
       "serialized_lookup": query_marker_path
    },
    "precomputed_stats": {
        "path": precomputed_path
    },
    "type_assignment": {
        "n_processors": 4,
        "normalization": "raw",
        "bootstrap_factor": 0.5,
        "bootstrap_iteration": 100
    }
}

# %%
runner = FromSpecifiedMarkersRunner(
    args=[],
    input_data=config
)
runner.run()
# Out:
# === Running Hierarchical Mapping 1.5.2 with config ===
# {
#   "log_level": "ERROR",
#   "extended_result_path": "results/human_nonneurons_mapping.json",
#   "verbose_stdout": true,
#   "type_assignment": {
#     "bootstrap_factor": 0.5,
#     "log_level": "ERROR",
#     "bootstrap_factor_lookup": null,
#     "rng_seed": 11235813,
#     "chunk_size": 10000,
#     "bootstrap_iteration": 100,
#     "n_processors": 4,
#     "min_markers": 10,
#     "n_runners_up": 5,
#     "normalization": "raw"
#   },
#   "cloud_safe": false,
#   "hdf5_result_path": null,
#   "log_path": null,
#   "query_markers": {
#     "collapse_markers": false,
#     "log_level": "ERROR",
#     "serialized_lookup": "data/Human.query_markers.20250507.json"
#   },
#   "csv_result_path": "results/human_nonneruons_mapping.csv",
#   "extended_result_dir": null,
#   "query_gene_id_col": null,
#   "max_gb": 100.0,
#   "obsm_clobber": false,
#   "verbose_csv": false,
#   "drop_level": null,
#   "summary_metadata_path": null,
#   "map_to_ensembl": false,
#   "nodes_to_drop": null,
#   "precomputed_stats": {
#     "path": "data/Human.precomputed_stats.20250507.h5",
#     "log_level": "ERROR"
#   },
#   "tmp_dir": null,
#   "flatten": false,
#   "obsm_key": null,
#   "query_path": "/Users/scott.daniel/KnowledgeEngineering/HMBA_BasalGanglia_Consensus_Taxonomy/examples/abc_cache/expression_matrices/WHB-10Xv3/20240330/WHB-10Xv3-Nonneurons-raw.h5ad"
# }
# ENV: is_torch_available: False
# ENV: is_cuda_available: False
# ENV: use_torch: False
# ENV: multiprocessing start method: spawn
# ENV: Python version: 3.12.9 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 12:55:12) [Clang 14.0.6 ]
# ENV: anndata version: 0.11.4
# ENV: numpy version: 2.2.5
# BENCHMARK: spent 1.1048e-03 seconds validating config and copying data
# using ../Human.precomputed_stats.20250507.h5 for precomputed_stats
# reading taxonomy_tree from ../Human.precomputed_stats.20250507.h5
# /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages/cell_type_mapper/cli/cli_log.py:73: UserWarning: numpy's internal parallelization is enabled. This could cause independent worker processes to compete for resources, degrading performance. We recommend setting the following environment variables to '1' to improve performance
# {
#   "NUMEXPR_NUM_THREADS": "",
#   "MKL_NUM_THREADS": "",
#   "OMP_NUM_THREADS": ""
# }
#   warnings.warn(msg)
# /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages/cell_type_mapper/taxonomy/utils.py:253: UserWarning: This taxonomy has no mapping from leaf_node -> rows in the cell by gene matrix
#   warnings.warn("This taxonomy has no mapping from leaf_node -> rows "
# /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages/cell_type_mapper/cli/cli_log.py:73: UserWarning: 18 marker genes were not present in the query dataset. They have been ignored
#   warnings.warn(msg)
# BENCHMARK: spent 5.9319e-02 seconds creating query marker cache
# Running CPU implementation of type assignment.
# 40000 of 888263 cells in 1.75e+00 min; predict 3.70e+01 min of 3.88e+01 min left
# 60000 of 888263 cells in 2.43e+00 min; predict 3.36e+01 min of 3.60e+01 min left
# 80000 of 888263 cells in 3.01e+00 min; predict 3.04e+01 min of 3.34e+01 min left
# 100000 of 888263 cells in 3.72e+00 min; predict 2.93e+01 min of 3.30e+01 min left
# 120000 of 888263 cells in 4.42e+00 min; predict 2.83e+01 min of 3.27e+01 min left
# 140000 of 888263 cells in 5.16e+00 min; predict 2.76e+01 min of 3.27e+01 min left
# 160000 of 888263 cells in 5.79e+00 min; predict 2.63e+01 min of 3.21e+01 min left
# 180000 of 888263 cells in 6.46e+00 min; predict 2.54e+01 min of 3.19e+01 min left
# 200000 of 888263 cells in 7.29e+00 min; predict 2.51e+01 min of 3.24e+01 min left
# 220000 of 888263 cells in 7.99e+00 min; predict 2.43e+01 min of 3.23e+01 min left
# 240000 of 888263 cells in 8.64e+00 min; predict 2.33e+01 min of 3.20e+01 min left
# 260000 of 888263 cells in 9.33e+00 min; predict 2.25e+01 min of 3.19e+01 min left
# 280000 of 888263 cells in 9.95e+00 min; predict 2.16e+01 min of 3.16e+01 min left
# 300000 of 888263 cells in 1.06e+01 min; predict 2.08e+01 min of 3.15e+01 min left
# 320000 of 888263 cells in 1.14e+01 min; predict 2.03e+01 min of 3.17e+01 min left
# 340000 of 888263 cells in 1.19e+01 min; predict 1.92e+01 min of 3.11e+01 min left
# 360000 of 888263 cells in 1.25e+01 min; predict 1.84e+01 min of 3.09e+01 min left
# 380000 of 888263 cells in 1.32e+01 min; predict 1.77e+01 min of 3.09e+01 min left
# 400000 of 888263 cells in 1.39e+01 min; predict 1.69e+01 min of 3.08e+01 min left
# 420000 of 888263 cells in 1.46e+01 min; predict 1.63e+01 min of 3.08e+01 min left
# 440000 of 888263 cells in 1.53e+01 min; predict 1.56e+01 min of 3.09e+01 min left
# 460000 of 888263 cells in 1.60e+01 min; predict 1.49e+01 min of 3.09e+01 min left
# 480000 of 888263 cells in 1.66e+01 min; predict 1.41e+01 min of 3.08e+01 min left
# 500000 of 888263 cells in 1.75e+01 min; predict 1.36e+01 min of 3.10e+01 min left
# 520000 of 888263 cells in 1.81e+01 min; predict 1.28e+01 min of 3.10e+01 min left
# 540000 of 888263 cells in 1.89e+01 min; predict 1.22e+01 min of 3.11e+01 min left
# 560000 of 888263 cells in 1.97e+01 min; predict 1.16e+01 min of 3.13e+01 min left
# 580000 of 888263 cells in 2.05e+01 min; predict 1.09e+01 min of 3.13e+01 min left
# 600000 of 888263 cells in 2.14e+01 min; predict 1.03e+01 min of 3.17e+01 min left
# 620000 of 888263 cells in 2.22e+01 min; predict 9.62e+00 min of 3.18e+01 min left
# 640000 of 888263 cells in 2.30e+01 min; predict 8.93e+00 min of 3.20e+01 min left
# 660000 of 888263 cells in 2.39e+01 min; predict 8.26e+00 min of 3.21e+01 min left
# 680000 of 888263 cells in 2.45e+01 min; predict 7.50e+00 min of 3.20e+01 min left
# 700000 of 888263 cells in 2.52e+01 min; predict 6.78e+00 min of 3.20e+01 min left
# 720000 of 888263 cells in 2.58e+01 min; predict 6.03e+00 min of 3.19e+01 min left
# 750000 of 888263 cells in 2.65e+01 min; predict 4.88e+00 min of 3.14e+01 min left
# 770000 of 888263 cells in 2.73e+01 min; predict 4.19e+00 min of 3.15e+01 min left
# 790000 of 888263 cells in 2.81e+01 min; predict 3.49e+00 min of 3.15e+01 min left
# 810000 of 888263 cells in 2.88e+01 min; predict 2.78e+00 min of 3.15e+01 min left
# 830000 of 888263 cells in 2.95e+01 min; predict 2.07e+00 min of 3.16e+01 min left
# 850000 of 888263 cells in 3.02e+01 min; predict 1.36e+00 min of 3.16e+01 min left
# 870000 of 888263 cells in 3.09e+01 min; predict 6.49e-01 min of 3.16e+01 min left
# BENCHMARK: spent 1.9071e+03 seconds assigning cell types
# Writing marker genes to output file
# MAPPING FROM SPECIFIED MARKERS RAN SUCCESSFULLY
# CLEANING UP

# %% [markdown]
# # Output of mapping file
#
# The results of our mapping are now in two files: the csv file pointed to by `csv_dst_path` and the JSON file pointed to by `json_dst_path`. Dedicated documentation of the the contents of the mapping output [can be found here.](https://github.com/AllenInstitute/cell_type_mapper/blob/main/docs/output.md)
#
# ## CSV output file
#
# The CSV file is effectively just a dataframe. For every cell at every taxonomy level, you have its assigned cell type (both as a guaranteed unique "label" and a more human readable "name") along with quality metrics assessing the confidence in the mapping (see the detailed documentation above).

# %%
mapping_csv = pd.read_csv(csv_dst_path, comment='#')

# %%
mapping_csv
# Out:
#                           cell_id     Neighborhood_label Neighborhood_name  \
# 0       10X362_3:TCAGTGAGTATTGACC  CS20250428_NEIGH_0001         Nonneuron
# 1       10X362_5:TCCGTGTGTGAAAGTT  CS20250428_NEIGH_0001         Nonneuron
# 2       10X362_5:CACGGGTAGAGCAGAA  CS20250428_NEIGH_0001         Nonneuron
# 3       10X362_5:GATTCTTGTATGTCAC  CS20250428_NEIGH_0001         Nonneuron
# 4       10X362_6:AGGACTTGTATCCTTT  CS20250428_NEIGH_0001         Nonneuron
# ...                           ...                    ...               ...
# 888258  10X194_8:GAAATGAGTTCGGCTG  CS20250428_NEIGH_0001         Nonneuron
# 888259  10X350_4:TTTACCATCGCACGAC  CS20250428_NEIGH_0001         Nonneuron
# 888260  10X225_1:AGAAGCGTCCATATGG  CS20250428_NEIGH_0001         Nonneuron
# 888261  10X221_5:TTGAACGCAGCCTTCT  CS20250428_NEIGH_0001         Nonneuron
# 888262  10X385_3:CTACCCAGTGGCGCTT  CS20250428_NEIGH_0001         Nonneuron
#
#         Neighborhood_bootstrapping_probability            Class_label  \
# 0                                          1.0  CS20250428_CLASS_0010
# 1                                          1.0  CS20250428_CLASS_0010
# 2                                          1.0  CS20250428_CLASS_0010
# 3                                          1.0  CS20250428_CLASS_0010
# 4                                          1.0  CS20250428_CLASS_0010
# ...                                        ...                    ...
# 888258                                     1.0  CS20250428_CLASS_0008
# 888259                                     1.0  CS20250428_CLASS_0008
# 888260                                     1.0  CS20250428_CLASS_0008
# 888261                                     1.0  CS20250428_CLASS_0008
# 888262                                     1.0  CS20250428_CLASS_0008
#
#        Class_name  Class_bootstrapping_probability         Subclass_label  \
# 0       OPC-Oligo                              1.0  CS20250428_SUBCL_0022
# 1       OPC-Oligo                              1.0  CS20250428_SUBCL_0022
# 2       OPC-Oligo                              1.0  CS20250428_SUBCL_0022
# 3       OPC-Oligo                              1.0  CS20250428_SUBCL_0022
# 4       OPC-Oligo                              1.0  CS20250428_SUBCL_0022
# ...           ...                              ...                    ...
# 888258     Immune                              1.0  CS20250428_SUBCL_0018
# 888259     Immune                              1.0  CS20250428_SUBCL_0018
# 888260     Immune                              1.0  CS20250428_SUBCL_0018
# 888261     Immune                              1.0  CS20250428_SUBCL_0018
# 888262     Immune                              1.0  CS20250428_SUBCL_0018
#
#           Subclass_name  Subclass_bootstrapping_probability  \
# 0       Oligodendrocyte                                1.00
# 1       Oligodendrocyte                                1.00
# 2       Oligodendrocyte                                1.00
# 3       Oligodendrocyte                                1.00
# 4       Oligodendrocyte                                1.00
# ...                 ...                                 ...
# 888258       Macrophage                                1.00
# 888259       Macrophage                                0.95
# 888260       Macrophage                                1.00
# 888261       Macrophage                                1.00
# 888262       Macrophage                                1.00
#
#                   Group_label     Group_name  Group_bootstrapping_probability  \
# 0       CS20250428_GROUP_0025   Oligo OPALIN                             0.69
# 1       CS20250428_GROUP_0026  Oligo PLEKHG1                             0.99
# 2       CS20250428_GROUP_0026  Oligo PLEKHG1                             0.58
# 3       CS20250428_GROUP_0026  Oligo PLEKHG1                             1.00
# 4       CS20250428_GROUP_0026  Oligo PLEKHG1                             1.00
# ...                       ...            ...                              ...
# 888258  CS20250428_GROUP_0001            BAM                             1.00
# 888259  CS20250428_GROUP_0001            BAM                             1.00
# 888260  CS20250428_GROUP_0001            BAM                             1.00
# 888261  CS20250428_GROUP_0001            BAM                             1.00
# 888262  CS20250428_GROUP_0001            BAM                             1.00
#
#                 Cluster_label Cluster_name Cluster_alias  \
# 0       CS20250428_CLUST_0227      Human-1       Human-1
# 1       CS20250428_CLUST_0231     Human-15      Human-15
# 2       CS20250428_CLUST_0231     Human-15      Human-15
# 3       CS20250428_CLUST_0230     Human-12      Human-12
# 4       CS20250428_CLUST_0231     Human-15      Human-15
# ...                       ...          ...           ...
# 888258  CS20250428_CLUST_0157     Human-71      Human-71
# 888259  CS20250428_CLUST_0160     Human-75      Human-75
# 888260  CS20250428_CLUST_0159     Human-74      Human-74
# 888261  CS20250428_CLUST_0160     Human-75      Human-75
# 888262  CS20250428_CLUST_0158     Human-73      Human-73
#
#         Cluster_bootstrapping_probability
# 0                                    0.55
# 1                                    0.99
# 2                                    1.00
# 3                                    1.00
# 4                                    1.00
# ...                                   ...
# 888258                               0.97
# 888259                               0.92
# 888260                               0.90
# 888261                               1.00
# 888262                               0.40
#
# [888263 rows x 17 columns]

# %% [markdown]
# ## JSON output file
#
# The JSON output contains everything in the CSV file, along with helpful metadata about your mapping run as [documented here](https://github.com/AllenInstitute/cell_type_mapper/blob/main/docs/output.md#json-output-file).

# %%
with open(json_dst_path, 'rb') as src:
    mapping_json = json.load(src)

# %% [markdown]
# For instance, to see the configuration parameters corresponding to your mapping run, you can look at

# %%
print(json.dumps(mapping_json['config'], indent=2))
# Out:
# {
#   "log_level": "ERROR",
#   "extended_result_path": "results/human_nonneurons_mapping.json",
#   "verbose_stdout": true,
#   "type_assignment": {
#     "bootstrap_factor": 0.5,
#     "log_level": "ERROR",
#     "bootstrap_factor_lookup": null,
#     "rng_seed": 11235813,
#     "chunk_size": 10000,
#     "bootstrap_iteration": 100,
#     "n_processors": 4,
#     "min_markers": 10,
#     "n_runners_up": 5,
#     "normalization": "raw"
#   },
#   "cloud_safe": false,
#   "hdf5_result_path": null,
#   "log_path": null,
#   "query_markers": {
#     "collapse_markers": false,
#     "log_level": "ERROR",
#     "serialized_lookup": "data/Human.query_markers.20250507.json"
#   },
#   "csv_result_path": "results/human_nonneruons_mapping.csv",
#   "extended_result_dir": null,
#   "query_gene_id_col": null,
#   "max_gb": 100.0,
#   "obsm_clobber": false,
#   "verbose_csv": false,
#   "drop_level": null,
#   "summary_metadata_path": null,
#   "map_to_ensembl": false,
#   "nodes_to_drop": null,
#   "precomputed_stats": {
#     "path": "data/Human.precomputed_stats.20250507.h5",
#     "log_level": "ERROR"
#   },
#   "tmp_dir": null,
#   "flatten": false,
#   "obsm_key": null,
#   "query_path": "/Users/scott.daniel/KnowledgeEngineering/HMBA_BasalGanglia_Consensus_Taxonomy/examples/abc_cache/expression_matrices/WHB-10Xv3/20240330/WHB-10Xv3-Nonneurons-raw.h5ad"
# }

# %% [markdown]
# The actual cell type assignments are stored as a list under `'results'` as in

# %%
print(json.dumps(mapping_json['results'][0], indent=2))
# Out:
# {
#   "CCN20250428_LEVEL_0": {
#     "assignment": "CS20250428_NEIGH_0001",
#     "bootstrapping_probability": 1.0,
#     "aggregate_probability": 1.0,
#     "avg_correlation": 0.7511638600643517,
#     "runner_up_assignment": [],
#     "runner_up_correlation": [],
#     "runner_up_probability": [],
#     "directly_assigned": true
#   },
#   "CCN20250428_LEVEL_1": {
#     "assignment": "CS20250428_CLASS_0010",
#     "bootstrapping_probability": 1.0,
#     "aggregate_probability": 1.0,
#     "avg_correlation": 0.8847336088608828,
#     "runner_up_assignment": [],
#     "runner_up_correlation": [],
#     "runner_up_probability": [],
#     "directly_assigned": true
#   },
#   "CCN20250428_LEVEL_2": {
#     "assignment": "CS20250428_SUBCL_0022",
#     "bootstrapping_probability": 1.0,
#     "aggregate_probability": 1.0,
#     "avg_correlation": 0.809104201147677,
#     "runner_up_assignment": [],
#     "runner_up_correlation": [],
#     "runner_up_probability": [],
#     "directly_assigned": true
#   },
#   "CCN20250428_LEVEL_3": {
#     "assignment": "CS20250428_GROUP_0025",
#     "bootstrapping_probability": 0.69,
#     "aggregate_probability": 0.69,
#     "avg_correlation": 0.626218144728874,
#     "runner_up_assignment": [
#       "CS20250428_GROUP_0026"
#     ],
#     "runner_up_correlation": [
#       0.6069362212706022
#     ],
#     "runner_up_probability": [
#       0.31
#     ],
#     "directly_assigned": true
#   },
#   "CCN20250428_LEVEL_4": {
#     "assignment": "CS20250428_CLUST_0227",
#     "bootstrapping_probability": 0.55,
#     "aggregate_probability": 0.3795,
#     "avg_correlation": 0.5614725591086703,
#     "runner_up_assignment": [
#       "CS20250428_CLUST_0228"
#     ],
#     "runner_up_correlation": [
#       0.5395855378047673
#     ],
#     "runner_up_probability": [
#       0.45
#     ],
#     "directly_assigned": true
#   },
#   "cell_id": "10X362_3:TCAGTGAGTATTGACC"
# }

# %% [markdown]
# One complication is that the cell type assignments are only referred to by their unique machine-readable labels in this file. Fortunately, the cell type taxonomy, along with the mapping between machine- and human-readable cell type labels is also provided in this file. The `TaxonomyTree` class provides a helpful interface with that data.

# %%
from cell_type_mapper.taxonomy.taxonomy_tree import TaxonomyTree

# %%
taxonomy = TaxonomyTree(data=mapping_json['taxonomy_tree'])
# Out:
# /Users/scott.daniel/miniconda3/envs/bg_documentation/lib/python3.12/site-packages/cell_type_mapper/taxonomy/utils.py:253: UserWarning: This taxonomy has no mapping from leaf_node -> rows in the cell by gene matrix
#   warnings.warn("This taxonomy has no mapping from leaf_node -> rows "

# %%
taxonomy.label_to_name(level='CCN20250428_LEVEL_3', label='CS20250428_GROUP_0025')
# Out:
# 'Oligo OPALIN'
